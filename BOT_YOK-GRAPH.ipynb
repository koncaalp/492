# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

import nltk

# %%
# Read in data
df = pd.read_csv('Reviews.csv')

print(df.shape)
# Out:
# (568454, 10)

# %%
df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 4                          0                       0      5  1350777600
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 568449  Great for sesame chicken..this is a good if no...
# 568450  I'm disappointed with the flavor. The chocolat...
# 568451  These stars are small, so you can give 10-15 o...
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 10 columns]

# %%
ax = df['Score'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()

# %%
print("Original DataFrame:")
print(df)

# Filter rows with description length greater than 15 characters
df_long_desc = df[df['Text'].str.len() > 15]

# Drop duplicates in the filtered DataFrame
df_long_desc_no_duplicates = df_long_desc.drop_duplicates(subset='Text', keep='first')

# Remove the rows with long descriptions from the original DataFrame
df_filtered = df[df['Text'].str.len() <= 15]

# Concatenate the filtered rows and the rows with unique long descriptions
df_result = pd.concat([df_filtered, df_long_desc_no_duplicates], ignore_index=True)

print("\nDataFrame after dropping duplicates in 'description' column for descriptions longer than 15 characters:")
print(df_result)
df = df_result
# Out:
# Original DataFrame:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 4                          0                       0      5  1350777600
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text
# 0       I have bought several of the Vitality canned d...
# 1       Product arrived labeled as Jumbo Salted Peanut...
# 2       This is a confection that has been around a fe...
# 3       If you are looking for the secret ingredient i...
# 4       Great taffy at a great price.  There was a wid...
# ...                                                   ...
# 568449  Great for sesame chicken..this is a good if no...
# 568450  I'm disappointed with the flavor. The chocolat...
# 568451  These stars are small, so you can give 10-15 o...
# 568452  These are the BEST treats for training and rew...
# 568453  I am very satisfied ,product is as advertised,...
#
# [568454 rows x 10 columns]
#
# DataFrame after dropping duplicates in 'description' column for descriptions longer than 15 characters:
#             Id   ProductId          UserId                      ProfileName  \
# 0       453669  B0001QYYUK  A3S7N11XRRTUU6                              Bob
# 1            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 3            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 4            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# ...        ...         ...             ...                              ...
# 393574  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 393575  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 393576  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 393577  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 393578  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          5                      14      1  1136246400
# 1                          1                       1      5  1303862400
# 2                          0                       0      1  1346976000
# 3                          1                       1      4  1219017600
# 4                          3                       3      2  1307923200
# ...                      ...                     ...    ...         ...
# 393574                     0                       0      5  1299628800
# 393575                     0                       0      2  1331251200
# 393576                     2                       2      5  1329782400
# 393577                     1                       1      5  1331596800
# 393578                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                             Not worth it
# 1                    Good Quality Dog Food
# 2                        Not as Advertised
# 3                    "Delight" says it all
# 4                           Cough Medicine
# ...                                    ...
# 393574                 Will not do without
# 393575                        disappointed
# 393576            Perfect for our maltipoo
# 393577  Favorite Training and reward treat
# 393578                         Great Honey
#
#                                                      Text
# 0                                            Not worth it
# 1       I have bought several of the Vitality canned d...
# 2       Product arrived labeled as Jumbo Salted Peanut...
# 3       This is a confection that has been around a fe...
# 4       If you are looking for the secret ingredient i...
# ...                                                   ...
# 393574  Great for sesame chicken..this is a good if no...
# 393575  I'm disappointed with the flavor. The chocolat...
# 393576  These stars are small, so you can give 10-15 o...
# 393577  These are the BEST treats for training and rew...
# 393578  I am very satisfied ,product is as advertised,...
#
# [393579 rows x 10 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset into a pandas DataFrame
df = pd.read_csv('Reviews.csv')
df_new = df.sample(n=1000)

# Plot a histogram of the Score column
df_new['Score'].hist()
plt.xlabel('Score')
plt.ylabel('Count')
plt.title('Distribution of Scores')
plt.show()

# Scatter plot of HelpfulnessNumerator vs. HelpfulnessDenominator
plt.scatter(df_new['HelpfulnessNumerator'], df_new['HelpfulnessDenominator'])
plt.xlabel('HelpfulnessNumerator')
plt.ylabel('HelpfulnessDenominator')
plt.title('Relationship between HelpfulnessNumerator and HelpfulnessDenominator')
plt.show()

# Box plot of Score grouped by ProfileName
df_new.boxplot(column='Score', by='ProfileName', rot=90)
plt.xlabel('ProfileName')
plt.ylabel('Score')
plt.title('Score Distribution by ProfileName')
plt.show()

# %%
# Read the dataset into a pandas DataFrame
df = pd.read_csv('Reviews.csv')

# Group the data by 'UserId' and calculate the count of reviews per user
user_review_counts = df.groupby('UserId')['Id'].count()

# Plot a histogram of the review counts per user
user_review_counts.hist()
plt.xlabel('Review Count')
plt.ylabel('User Count')
plt.title('Distribution of Review Counts per User')
plt.show()

# Get the top 10 users with the highest review counts
top_users = user_review_counts.nlargest(10)

# Plot a bar chart of the top users
top_users.plot(kind='bar')
plt.xlabel('User ID')
plt.ylabel('Review Count')
plt.title('Top 10 Users with Highest Review Counts')
plt.show()

# %%
# Read the dataset into a pandas DataFrame
df = pd.read_csv('Reviews.csv')

# Calculate the average score for each product
product_avg_scores = df.groupby('ProductId')['Score'].mean()

# Plot a histogram of the average scores per product
product_avg_scores.hist()
plt.xlabel('Average Score')
plt.ylabel('Product Count')
plt.title('Distribution of Average Scores per Product')
plt.show()

# Get the top 10 products with the highest average scores
top_products = product_avg_scores.nlargest(10)

# Plot a bar chart of the top products
top_products.plot(kind='bar')
plt.xlabel('Product ID')
plt.ylabel('Average Score')
plt.title('Top 10 Products with Highest Average Scores')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the dataset into a pandas DataFrame
df = pd.read_csv('Reviews.csv')
df_new = df.sample(n=100)

# Plot a histogram of the Score column
df_new['Score'].hist()
plt.xlabel('Score')
plt.ylabel('Count')
plt.title('Distribution of Scores')
plt.show()

# Scatter plot of HelpfulnessNumerator vs. HelpfulnessDenominator
plt.scatter(df_new['HelpfulnessNumerator'], df_new['HelpfulnessDenominator'])
plt.xlabel('HelpfulnessNumerator')
plt.ylabel('HelpfulnessDenominator')
plt.title('Relationship between HelpfulnessNumerator and HelpfulnessDenominator')
plt.show()

# %%
df_sorted = df.sort_values('HelpfulnessDenominator', ascending=False)
df_sorted.head(30)
# Out:
#             Id   ProductId          UserId                     ProfileName  \
# 207712  207713  B00012182G  A1JUGIQDY6UYSM           BabbChuck "BabbChuck"
# 190733  190734  B000FI4O90  A1GQGYROVZVW49                      P. Schmidt
# 566779  566780  B001PQTYN2  A1QB2Y8GSME58Y               Benjamin Chodroff
# 235722  235723  B001F10XUU  A39V22BIBUMMB3       Y. Hughes "Notmyrealname"
# 222937  222938  B000UUWECC   AU3GYRAKBUAEU                      Jon Norris
# 373575  373576  B009K2BBQG  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 130478  130479  B005F3IAPE  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 96104    96105  B00859FH7O  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 297366  297367  B0069GOKGE  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 467800  467801  B0065G59F4  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 293135  293136  B008VQ01Y0  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 385450  385451  B0051SU0OW  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 210511  210512  B005FKRTO0  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 287184  287185  B009K2BBT8  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 116802  116803  B008F2K1YU  A1B4MIXYVIKMU2  D. Truong "Duke of New Mexico"
# 303074  303075  B005K0L2U2  A3RGPBC7HZA8V4               EMC "neelie klop"
# 375916  375917  B005QOLSJ2  A3RGPBC7HZA8V4               EMC "neelie klop"
# 88407    88408  B001D0KG4Q   A1RCLICH0OO12                        R. Hiltz
# 190734  190735  B000FI4O90  A3KTISKYS55LQ7          M. Boomgarden "Mike B"
# 433675  433676  B001LQCOIS  A233OPIX0YGN98                         ic "ic"
# 373776  373777  B004WTHCO2  A233OPIX0YGN98                         ic "ic"
# 268064  268065  B00032G1S0  A37GS73Z3Q6TMY                   biggestbamboo
# 241668  241669  B0081XPTBS  A13FB7U0KAPE5G                         S. Chee
# 358113  358114  B0032CJPOK  A13FB7U0KAPE5G                         S. Chee
# 467801  467802  B0065G59F4  A10PV6AP8SXEDI                      J. Goldman
# 297367  297368  B0069GOKGE  A10PV6AP8SXEDI                      J. Goldman
# 96105    96106  B00859FH7O  A10PV6AP8SXEDI                      J. Goldman
# 373576  373577  B009K2BBQG  A10PV6AP8SXEDI                      J. Goldman
# 385451  385452  B0051SU0OW  A10PV6AP8SXEDI                      J. Goldman
# 130479  130480  B005F3IAPE  A10PV6AP8SXEDI                      J. Goldman
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 207712                   844                     923      3  1252368000
# 190733                   866                     878      5  1164672000
# 566779                   808                     815      5  1260748800
# 235722                   580                     593      1  1309564800
# 222937                   491                     569      3  1212278400
# 373575                   559                     562      5  1314921600
# 130478                   559                     562      5  1314921600
# 96104                    559                     562      5  1314921600
# 297366                   559                     562      5  1314921600
# 467800                   559                     562      5  1314921600
# 293135                   559                     562      5  1314921600
# 385450                   559                     562      5  1314921600
# 210511                   559                     562      5  1314921600
# 287184                   559                     562      5  1314921600
# 116802                   559                     562      5  1314921600
# 303074                   538                     544      5  1292284800
# 375916                   538                     544      5  1292284800
# 88407                    536                     539      5  1185840000
# 190734                   524                     536      2  1188259200
# 433675                   488                     496      5  1235520000
# 373776                   488                     496      5  1235520000
# 268064                   466                     488      5  1155168000
# 241668                   436                     486      1  1262995200
# 358113                   436                     486      1  1262995200
# 467801                   472                     477      5  1312848000
# 297367                   472                     477      5  1312848000
# 96105                    472                     477      5  1312848000
# 373576                   472                     477      5  1312848000
# 385451                   472                     477      5  1312848000
# 130479                   472                     477      5  1312848000
#
#                                                   Summary  \
# 207712                                Whole Rabbit - NOT!
# 190733               Works as Advertised - Classy Product
# 566779                              sauce not for mortals
# 235722                         Lost in Translation: Truth
# 222937        not bad stuff, but I have serious questions
# 373575  Works great! But how does it compare to Solofi...
# 130478  Works great! But how does it compare to Solofi...
# 96104   Works great! But how does it compare to Solofi...
# 297366  Works great! But how does it compare to Solofi...
# 467800  Works great! But how does it compare to Solofi...
# 293135  Works great! But how does it compare to Solofi...
# 385450  Works great! But how does it compare to Solofi...
# 210511  Works great! But how does it compare to Solofi...
# 287184  Works great! But how does it compare to Solofi...
# 116802  Works great! But how does it compare to Solofi...
# 303074                                      Money saver!!
# 375916                                      Money saver!!
# 88407                  Good sampler, but what's included?
# 190734           A Nice Item That Makes a Horrible Racket
# 433675                              A Slacker Mom's dream
# 373776                              A Slacker Mom's dream
# 268064                                    Serious Problem
# 241668                         Toxic Hexane in Formula???
# 358113                         Toxic Hexane in Formula???
# 467801                         This filter works PERFECT!
# 297367                         This filter works PERFECT!
# 96105                          This filter works PERFECT!
# 373576                         This filter works PERFECT!
# 385451                         This filter works PERFECT!
# 130479                         This filter works PERFECT!
#
#                                                      Text
# 207712  I ordered one of these Fresh "Whole" Rabbits, ...
# 190733  see update at end of review<br /><br />*******...
# 566779  I purchased a burrito from a small shop a few ...
# 235722  This product is called "Hunmatsu-RyokuCha," in...
# 222937  Coconut water is the liquid inside an unopened...
# 373575  This Ecobrew reusable Keurig K-cup is great fo...
# 130478  This Ecobrew reusable Keurig K-cup is great fo...
# 96104   This Ecobrew reusable Keurig K-cup is great fo...
# 297366  This Ecobrew reusable Keurig K-cup is great fo...
# 467800  This Ecobrew reusable Keurig K-cup is great fo...
# 293135  This Ecobrew reusable Keurig K-cup is great fo...
# 385450  This Ecobrew reusable Keurig K-cup is great fo...
# 210511  This Ecobrew reusable Keurig K-cup is great fo...
# 287184  This Ecobrew reusable Keurig K-cup is great fo...
# 116802  This Ecobrew reusable Keurig K-cup is great fo...
# 303074  As a huge fan of Keurig brewing, I was delight...
# 375916  As a huge fan of Keurig brewing, I was delight...
# 88407   Good opportunity to sample some of the various...
# 190734  I bought an AeroGarden for my wife back in May...
# 433675  I love this gadget.  Compact, all-in-one, easy...
# 373776  I love this gadget.  Compact, all-in-one, easy...
# 268064  This product copiously leaks out of my nose wh...
# 241668  To be honest, I have never written a review, n...
# 358113  To be honest, I have never written a review, n...
# 467801  Seriously, I love my Keurig. I love the conven...
# 297367  Seriously, I love my Keurig. I love the conven...
# 96105   Seriously, I love my Keurig. I love the conven...
# 373576  Seriously, I love my Keurig. I love the conven...
# 385451  Seriously, I love my Keurig. I love the conven...
# 130479  Seriously, I love my Keurig. I love the conven...

# %%
median_score = df['HelpfulnessDenominator'].mean()
median_score
# Out:
# 2.2288100708236724

# %%
um_zero = (df['HelpfulnessDenominator'] == 0).sum()
um_zero
# Out:
# 270052

# %%
df['HelpfulnessRatio'] = df.apply(lambda row: row['HelpfulnessNumerator'] / row['HelpfulnessDenominator'] if row['HelpfulnessDenominator'] != 0 else -1, axis=1)

# %%
hist, bins, _ = plt.hist(df['HelpfulnessRatio'])

# Get the count of rows in each bin
bin_counts = pd.cut(df['HelpfulnessRatio'], bins=bins).value_counts(sort=False)

# Print the bin counts
print(bin_counts)
# Out:
# (-1.0, -0.6]         0
# (-0.6, -0.2]         0
# (-0.2, 0.2]      37896
# (0.2, 0.6]       37475
# (0.6, 1.0]      223029
# (1.0, 1.4]           0
# (1.4, 1.8]           1
# (1.8, 2.2]           0
# (2.2, 2.6]           0
# (2.6, 3.0]           1
# Name: HelpfulnessRatio, dtype: int64

# %%
plt.hist(df['HelpfulnessRatio'], bins='auto', edgecolor='black')
plt.xlabel('HelpfulnessRatio')
plt.ylabel('Frequency')
plt.title('Histogram of HelpfulnessRatio with Automatic Bin Sizes')
plt.show()

# Print the amount of rows in each bin
counts, bin_edges = np.histogram(df['HelpfulnessRatio'], bins='auto')
for i in range(len(counts)):
    print(f"Bin {i+1}: Range ({bin_edges[i]}, {bin_edges[i+1]}), Rows: {counts[i]}")
# Out:
# Bin 1: Range (-1.0, -0.9518072289156626), Rows: 270052
# Bin 2: Range (-0.9518072289156626, -0.9036144578313253), Rows: 0
# Bin 3: Range (-0.9036144578313253, -0.8554216867469879), Rows: 0
# Bin 4: Range (-0.8554216867469879, -0.8072289156626506), Rows: 0
# Bin 5: Range (-0.8072289156626506, -0.7590361445783133), Rows: 0
# Bin 6: Range (-0.7590361445783133, -0.7108433734939759), Rows: 0
# Bin 7: Range (-0.7108433734939759, -0.6626506024096386), Rows: 0
# Bin 8: Range (-0.6626506024096386, -0.6144578313253012), Rows: 0
# Bin 9: Range (-0.6144578313253012, -0.5662650602409638), Rows: 0
# Bin 10: Range (-0.5662650602409638, -0.5180722891566265), Rows: 0
# Bin 11: Range (-0.5180722891566265, -0.4698795180722891), Rows: 0
# Bin 12: Range (-0.4698795180722891, -0.4216867469879517), Rows: 0
# Bin 13: Range (-0.4216867469879517, -0.37349397590361444), Rows: 0
# Bin 14: Range (-0.37349397590361444, -0.32530120481927705), Rows: 0
# Bin 15: Range (-0.32530120481927705, -0.27710843373493976), Rows: 0
# Bin 16: Range (-0.27710843373493976, -0.22891566265060237), Rows: 0
# Bin 17: Range (-0.22891566265060237, -0.18072289156626498), Rows: 0
# Bin 18: Range (-0.18072289156626498, -0.1325301204819277), Rows: 0
# Bin 19: Range (-0.1325301204819277, -0.0843373493975903), Rows: 0
# Bin 20: Range (-0.0843373493975903, -0.03614457831325302), Rows: 0
# Bin 21: Range (-0.03614457831325302, 0.012048192771084487), Rows: 33775
# Bin 22: Range (0.012048192771084487, 0.06024096385542177), Rows: 263
# Bin 23: Range (0.06024096385542177, 0.10843373493975905), Rows: 631
# Bin 24: Range (0.10843373493975905, 0.15662650602409656), Rows: 1164
# Bin 25: Range (0.15662650602409656, 0.20481927710843384), Rows: 2071
# Bin 26: Range (0.20481927710843384, 0.2530120481927711), Rows: 2503
# Bin 27: Range (0.2530120481927711, 0.3012048192771084), Rows: 866
# Bin 28: Range (0.3012048192771084, 0.3493975903614459), Rows: 5500
# Bin 29: Range (0.3493975903614459, 0.3975903614457832), Rows: 592
# Bin 30: Range (0.3975903614457832, 0.4457831325301205), Rows: 2453
# Bin 31: Range (0.4457831325301205, 0.493975903614458), Rows: 295
# Bin 32: Range (0.493975903614458, 0.5421686746987953), Rows: 21843
# Bin 33: Range (0.5421686746987953, 0.5903614457831325), Rows: 1308
# Bin 34: Range (0.5903614457831325, 0.63855421686747), Rows: 2934
# Bin 35: Range (0.63855421686747, 0.6867469879518073), Rows: 10762
# Bin 36: Range (0.6867469879518073, 0.7349397590361446), Rows: 2165
# Bin 37: Range (0.7349397590361446, 0.7831325301204821), Rows: 7378
# Bin 38: Range (0.7831325301204821, 0.8313253012048194), Rows: 4644
# Bin 39: Range (0.8313253012048194, 0.8795180722891567), Rows: 6371
# Bin 40: Range (0.8795180722891567, 0.927710843373494), Rows: 4272
# Bin 41: Range (0.927710843373494, 0.9759036144578315), Rows: 2865
# Bin 42: Range (0.9759036144578315, 1.024096385542169), Rows: 183745
# Bin 43: Range (1.024096385542169, 1.072289156626506), Rows: 0
# Bin 44: Range (1.072289156626506, 1.1204819277108435), Rows: 0
# Bin 45: Range (1.1204819277108435, 1.168674698795181), Rows: 0
# Bin 46: Range (1.168674698795181, 1.216867469879518), Rows: 0
# Bin 47: Range (1.216867469879518, 1.2650602409638556), Rows: 0
# Bin 48: Range (1.2650602409638556, 1.3132530120481931), Rows: 0
# Bin 49: Range (1.3132530120481931, 1.3614457831325302), Rows: 0
# Bin 50: Range (1.3614457831325302, 1.4096385542168677), Rows: 0
# Bin 51: Range (1.4096385542168677, 1.4578313253012047), Rows: 0
# Bin 52: Range (1.4578313253012047, 1.5060240963855422), Rows: 1
# Bin 53: Range (1.5060240963855422, 1.5542168674698797), Rows: 0
# Bin 54: Range (1.5542168674698797, 1.6024096385542168), Rows: 0
# Bin 55: Range (1.6024096385542168, 1.6506024096385543), Rows: 0
# Bin 56: Range (1.6506024096385543, 1.6987951807228918), Rows: 0
# Bin 57: Range (1.6987951807228918, 1.7469879518072289), Rows: 0
# Bin 58: Range (1.7469879518072289, 1.7951807228915664), Rows: 0
# Bin 59: Range (1.7951807228915664, 1.8433734939759039), Rows: 0
# Bin 60: Range (1.8433734939759039, 1.891566265060241), Rows: 0
# Bin 61: Range (1.891566265060241, 1.9397590361445785), Rows: 0
# Bin 62: Range (1.9397590361445785, 1.987951807228916), Rows: 0
# Bin 63: Range (1.987951807228916, 2.036144578313253), Rows: 0
# Bin 64: Range (2.036144578313253, 2.0843373493975905), Rows: 0
# Bin 65: Range (2.0843373493975905, 2.132530120481928), Rows: 0
# Bin 66: Range (2.132530120481928, 2.180722891566265), Rows: 0
# Bin 67: Range (2.180722891566265, 2.2289156626506026), Rows: 0
# Bin 68: Range (2.2289156626506026, 2.27710843373494), Rows: 0
# Bin 69: Range (2.27710843373494, 2.325301204819277), Rows: 0
# Bin 70: Range (2.325301204819277, 2.3734939759036147), Rows: 0
# Bin 71: Range (2.3734939759036147, 2.421686746987952), Rows: 0
# Bin 72: Range (2.421686746987952, 2.4698795180722892), Rows: 0
# Bin 73: Range (2.4698795180722892, 2.5180722891566267), Rows: 0
# Bin 74: Range (2.5180722891566267, 2.5662650602409642), Rows: 0
# Bin 75: Range (2.5662650602409642, 2.6144578313253013), Rows: 0
# Bin 76: Range (2.6144578313253013, 2.662650602409639), Rows: 0
# Bin 77: Range (2.662650602409639, 2.7108433734939763), Rows: 0
# Bin 78: Range (2.7108433734939763, 2.7590361445783134), Rows: 0
# Bin 79: Range (2.7590361445783134, 2.807228915662651), Rows: 0
# Bin 80: Range (2.807228915662651, 2.855421686746988), Rows: 0
# Bin 81: Range (2.855421686746988, 2.9036144578313254), Rows: 0
# Bin 82: Range (2.9036144578313254, 2.951807228915663), Rows: 0
# Bin 83: Range (2.951807228915663, 3.0), Rows: 1

# %%
df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1            2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4            5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
# ...        ...         ...             ...                              ...
# 568449  568450  B001EO7N10  A28KG5XORO54AY                 Lettie D. Carter
# 568450  568451  B003S1WTCU  A3I8AFVPEE8KI5                        R. Sawyer
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
# 568453  568454  B001LR2CU2  A3LGQPJCZVL9UC                         srfell17
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 1                          0                       0      1  1346976000
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 4                          0                       0      5  1350777600
# ...                      ...                     ...    ...         ...
# 568449                     0                       0      5  1299628800
# 568450                     0                       0      2  1331251200
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
# 568453                     0                       0      5  1338422400
#
#                                    Summary  \
# 0                    Good Quality Dog Food
# 1                        Not as Advertised
# 2                    "Delight" says it all
# 3                           Cough Medicine
# 4                              Great taffy
# ...                                    ...
# 568449                 Will not do without
# 568450                        disappointed
# 568451            Perfect for our maltipoo
# 568452  Favorite Training and reward treat
# 568453                         Great Honey
#
#                                                      Text  HelpfulnessRatio
# 0       I have bought several of the Vitality canned d...               1.0
# 1       Product arrived labeled as Jumbo Salted Peanut...              -1.0
# 2       This is a confection that has been around a fe...               1.0
# 3       If you are looking for the secret ingredient i...               1.0
# 4       Great taffy at a great price.  There was a wid...              -1.0
# ...                                                   ...               ...
# 568449  Great for sesame chicken..this is a good if no...              -1.0
# 568450  I'm disappointed with the flavor. The chocolat...              -1.0
# 568451  These stars are small, so you can give 10-15 o...               1.0
# 568452  These are the BEST treats for training and rew...               1.0
# 568453  I am very satisfied ,product is as advertised,...              -1.0
#
# [568454 rows x 11 columns]

# %%
from math import sqrt

def wilson_lower_bound(helpful_votes, total_votes, confidence=0.95):
    """
    Calculate the lower bound of Wilson Score Interval.
    
    helpful_votes: int, number of helpful votes (helpfulnessNominator)
    total_votes: int, total number of votes (helpfulnessDenominator)
    confidence: float, the desired confidence level (default: 0.95)
    
    Returns the lower bound of Wilson Score Interval as a float.
    """
    if total_votes == 0:
        return 0
    z = 1.96  # z-score for 95% confidence interval
    phat = float(helpful_votes) / total_votes
    inner_sqrt = (phat * (1 - phat) + z**2 / (4 * total_votes)) / total_votes
    if inner_sqrt < 0:
        inner_sqrt = 0  # Prevent math domain error
    denominator = 1 + z**2/total_votes
    numerator = phat + z**2 / (2 * total_votes) - z * sqrt(inner_sqrt)
    return numerator / denominator

# %%
df['wilson_score'] = df.apply(lambda row: wilson_lower_bound(row['HelpfulnessNumerator'], row['HelpfulnessDenominator']), axis=1)

# Set a threshold for wilson_score to filter out low helpfulness reviews
threshold = 0.15
filtered_df = df[df['wilson_score'] >= threshold]

# You can also sort the DataFrame by the Wilson Score
sorted_df = df.sort_values(by='wilson_score', ascending=False)

# %%
filtered_df
# Out:
#             Id   ProductId          UserId                      ProfileName  \
# 0            1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 2            3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3            4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 8            9  B000E7L2R4  A1MZYO9TZK0BBI                         R. James
# 10          11  B0001PB9FE  A3HDKO7OW0QNK4                     Canadian Fan
# ...        ...         ...             ...                              ...
# 568440  568441  B005ZC0RRO  A2TO5R8QLIITEF                              SAK
# 568444  568445  B001EO7N10  A2SD7TY3IOX69B       BayBay "BayBay Knows Best"
# 568445  568446  B001EO7N10  A2E5C8TTAED4CQ                    S. Linkletter
# 568451  568452  B004I613EE  A121AA1GQV751Z                    pksd "pk_007"
# 568452  568453  B004I613EE   A3IBEVCTXKNOH          Kathy A. Welch "katwel"
#
#         HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                          1                       1      5  1303862400
# 2                          1                       1      4  1219017600
# 3                          3                       3      2  1307923200
# 8                          1                       1      5  1322006400
# 10                         1                       1      5  1107820800
# ...                      ...                     ...    ...         ...
# 568440                     1                       1      5  1323734400
# 568444                     3                       3      5  1245369600
# 568445                     2                       2      5  1268006400
# 568451                     2                       2      5  1329782400
# 568452                     1                       1      5  1331596800
#
#                                                 Summary  \
# 0                                 Good Quality Dog Food
# 2                                 "Delight" says it all
# 3                                        Cough Medicine
# 8                                            Yay Barley
# 10                      The Best Hot Sauce in the World
# ...                                                 ...
# 568440  Delicious, all natural and allergy free treats!
# 568444                   Best Value for Chinese 5 Spice
# 568445                                Five Spice Powder
# 568451                         Perfect for our maltipoo
# 568452               Favorite Training and reward treat
#
#                                                      Text  HelpfulnessRatio  \
# 0       I have bought several of the Vitality canned d...               1.0
# 2       This is a confection that has been around a fe...               1.0
# 3       If you are looking for the secret ingredient i...               1.0
# 8       Right now I'm mostly just sprouting this so my...               1.0
# 10      I don't know if it's the cactus or the tequila...               1.0
# ...                                                   ...               ...
# 568440  Indie Candy's gummies are absolutely delicious...               1.0
# 568444  As a foodie, I use a lot of Chinese 5 Spice po...               1.0
# 568445  You can make this mix yourself, but the Star A...               1.0
# 568451  These stars are small, so you can give 10-15 o...               1.0
# 568452  These are the BEST treats for training and rew...               1.0
#
#         wilson_score
# 0           0.206543
# 2           0.206543
# 3           0.438494
# 8           0.206543
# 10          0.206543
# ...              ...
# 568440      0.206543
# 568444      0.438494
# 568445      0.342372
# 568451      0.342372
# 568452      0.206543
#
# [233220 rows x 12 columns]
